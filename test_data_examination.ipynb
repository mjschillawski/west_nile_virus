# %%
import pandas as pd

# %%
test = pd.read_csv('assets/input/test.csv')

# %%
test.head(20)
# Out:
#     Id        Date                                            Address  \
# 0    1  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1    2  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2    3  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 3    4  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 4    5  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 5    6  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 6    7  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 7    8  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 8    9  2008-06-11  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 9   10  2008-06-11  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 10  11  2008-06-11  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 11  12  2008-06-11  6200 North Mandell Avenue, Chicago, IL 60646, USA
# ...

# %%
test.columns
# Out:
# Index(['Id', 'Date', 'Address', 'Species', 'Block', 'Street', 'Trap',
#        'AddressNumberAndStreet', 'Latitude', 'Longitude', 'AddressAccuracy'],
#       dtype='object')

# %%
test['Trap'].value_counts().sort_index()
# Out:
# T001      760
# T002      857
# T002A     760
# T002B     760
# T003      780
# T004      760
# T005      760
# T006      760
# T007      760
# T008      822
# T009     1528
# T011      814
# T012      781
# T013      769
# T014      762
# T015      760
# T016      775
# T017      760
# T018      760
# T019      760
# T025      760
# T027      803
# T028      783
# T030      771
# T031      763
# T033      762
# T034      760
# T035     1520
# T036      760
# T037      760
#          ...
# T206      760
# T209      763
# T212      773
# T215      760
# T218      767
# T218A     760
# T218B     762
# T218C     762
# T219      760
# T220      776
# T221      769
# T222      762
# T223      774
# T224      761
# T225      766
# T226      760
# T227      762
# T228      764
# T229      760
# T230      762
# T231      781
# T232      760
# T233      765
# T234      760
# T235      761
# T236      763
# T237      760
# T238      760
# T900     1468
# T903      784
# ...

# %%
test[test.duplicated(['Date','Trap','Species'],keep=False)].sort_values(['Date','Trap','Species'])
# Out:
#             Id        Date                                           Address  \
# 151        152  2008-06-11  9100 West Higgins Avenue, Chicago, IL 60656, USA
# 935        936  2008-06-11   9100 West Higgins Road, Rosemont, IL 60018, USA
# 146        147  2008-06-11  9100 West Higgins Avenue, Chicago, IL 60656, USA
# 930        931  2008-06-11   9100 West Higgins Road, Rosemont, IL 60018, USA
# 144        145  2008-06-11  9100 West Higgins Avenue, Chicago, IL 60656, USA
# 928        929  2008-06-11   9100 West Higgins Road, Rosemont, IL 60018, USA
# 145        146  2008-06-11  9100 West Higgins Avenue, Chicago, IL 60656, USA
# 929        930  2008-06-11   9100 West Higgins Road, Rosemont, IL 60018, USA
# 147        148  2008-06-11  9100 West Higgins Avenue, Chicago, IL 60656, USA
# 931        932  2008-06-11   9100 West Higgins Road, Rosemont, IL 60018, USA
# 149        150  2008-06-11  9100 West Higgins Avenue, Chicago, IL 60656, USA
# ...
